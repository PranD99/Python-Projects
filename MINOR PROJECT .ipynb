# %% [markdown]
# MINOR PROJECT MACHINE LEARNING ( May Batch - 1 )
#
# Prantik Dutta - 1905693@kiit.ac.in - prantik.dutta1000@gmail.com

# %% [markdown]
# Objective of the analysis:
# To understand how the student's performance (test scores) is affected by the other variables (Gender, Ethnicity, Parental level of education, Lunch, Test preparation course).
#
# AIM:
# To analyse insights in the dataset.
# To understand the connection between the variables and to uncover the underlying structure.
# To extract the import variables.
# To detect anomalies.
# To test the underlying assumptions.
# Provide insights with suitable graphs and visualizations.
# Write all the inferences with supporting analysis and visualizations.
#
# Importing all the required python libraries.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Reading the csv file-

# %%
data = pd.read_csv(r"C:\Users\KIIT\Desktop\StudentsPerformance.csv")

# %% [markdown]
# To display data-

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data.shape
# Out:
# (1000, 8)

# %% [markdown]
# Checking for missing values-

# %%
data.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# So there are no missing values in the dataset.
#
# Now, checking data type of all the columns-

# %%
data.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %% [markdown]
# This displays all the column names along with their data types.
#
# Now, we want to analyse the values of the columns and check whether they are numerical or categorical.

# %%
print("Gender")
data['gender'].value_counts()
# Out:
# Gender
# female    518
# male      482
# Name: gender, dtype: int64

# %%
sns.countplot(x=data['gender'])
plt.title("Gender wise numerical representation")
# Out:
# Text(0.5, 1.0, 'Gender wise numerical representation')

# %%
print("Parental Level of Education")
data['parental level of education'].value_counts()
# Out:
# Parental Level of Education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
sns.countplot(x=data['parental level of education'])
plt.title("Parent's Education")
# Out:
# Text(0.5, 1.0, "Parent's Education")

# %%
print("Race/Ethnicity")
data['race/ethnicity'].value_counts()
# Out:
# Race/Ethnicity
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: race/ethnicity, dtype: int64

# %%
sns.countplot(x=data['race/ethnicity'])
plt.title("Race/Ethnicity wise numerical representation")
# Out:
# Text(0.5, 1.0, 'Race/Ethnicity wise numerical representation')

# %%
print("Lunch")
data['lunch'].value_counts()
# Out:
# Lunch
# standard        645
# free/reduced    355
# Name: lunch, dtype: int64

# %%
sns.countplot(x=data['lunch'])
plt.title("Lunch Type")
# Out:
# Text(0.5, 1.0, 'Lunch Type')

# %%
print("Test Preparation Course")
data['test preparation course'].value_counts()
# Out:
# Test Preparation Course
# none         642
# completed    358
# Name: test preparation course, dtype: int64

# %%
sns.countplot(x=data['test preparation course'])
plt.title('Status of completion')
# Out:
# Text(0.5, 1.0, 'Status of completion')

# %%
print("Math Score")
data['math score'].value_counts()
# Out:
# Math Score
# 65    36
# 62    35
# 59    32
# 69    32
# 73    27
#       ..
# 22     1
# 19     1
# 18     1
# 8      1
# 0      1
# Name: math score, Length: 81, dtype: int64

# %%
print("Reading Score")
data['reading score'].value_counts()
# Out:
# Reading Score
# 72    34
# 74    33
# 64    32
# 73    30
# 67    30
#       ..
# 32     1
# 28     1
# 26     1
# 23     1
# 17     1
# Name: reading score, Length: 72, dtype: int64

# %%
print("Writing Score")
data['writing score'].value_counts()
# Out:
# Writing Score
# 74    35
# 70    33
# 68    31
# 73    28
# 62    27
#       ..
# 23     1
# 22     1
# 19     1
# 15     1
# 10     1
# Name: writing score, Length: 77, dtype: int64

# %% [markdown]
# We can see from the above that the columns, "gender", "parental level of education", "race/ethnicity", "lunch" and "test preparation course" are categorical variables and "math score", "reading score" and "writing score" are numerical variables. Since marks are always numerical, therefore the columns, "math score", "reading score" and "writing score" contain numerical values.
#
# Now, adding columns "total" and "average" to the dataset.

# %%
data['total'] = data['math score'] + data['reading score'] + data['writing score']
data['average'] = data['total'] / 3

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  total  \
# 0                    none          72             72             74    218
# 1               completed          69             90             88    247
# 2                    none          90             95             93    278
# 3                    none          47             57             44    148
# 4                    none          76             78             75    229
#
#      average
# 0  72.666667
# 1  82.333333
# 2  92.666667
# 3  49.333333
# 4  76.333333

# %%
data.describe()
# Out:
#        math score  reading score  writing score        total      average
# count  1000.00000    1000.000000    1000.000000  1000.000000  1000.000000
# mean     66.08900      69.169000      68.054000   203.312000    67.770667
# std      15.16308      14.600192      15.195657    42.771978    14.257326
# min       0.00000      17.000000      10.000000    27.000000     9.000000
# 25%      57.00000      59.000000      57.750000   175.000000    58.333333
# 50%      66.00000      70.000000      69.000000   205.000000    68.333333
# 75%      77.00000      79.000000      79.000000   233.000000    77.666667
# max     100.00000     100.000000     100.000000   300.000000   100.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
#  8   total                        1000 non-null   int64
#  9   average                      1000 non-null   float64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 78.2+ KB

# %%
data.groupby("parental level of education", as_index=True)[["math score", "reading score", "writing score"]].mean()
# Out:
#                              math score  reading score  writing score
# parental level of education
# associate's degree            67.882883      70.927928      69.896396
# bachelor's degree             69.389831      73.000000      73.381356
# high school                   62.137755      64.704082      62.448980
# master's degree               69.745763      75.372881      75.677966
# some college                  67.128319      69.460177      68.840708
# some high school              63.497207      66.938547      64.888268

# %% [markdown]
# For the distribution of scores-

# %%
sns.distplot(data['math score'])

# %%
sns.distplot(data['reading score'])

# %%
sns.distplot(data['writing score'])

# %%
sns.distplot(data['average'])

# %%
sns.pairplot(data)

# %%
data['average'].plot(kind='hist', bins=100, figsize=(7,7))
plt.xlabel("Average Score")
plt.ylabel("Frequency")
plt.title("Scores Distribution")
plt.show()

# %% [markdown]
# Now, analyzing the average score of all the students on the basis of "race/ethnicity", "parental level of education" and "test preparation course"-

# %%
sns.barplot(data['race/ethnicity'], data['average'])

# %%
sns.barplot(data['parental level of education'], data['average'])

# %%
sns.barplot(data['test preparation course'], data['average'])

# %% [markdown]
# Now, lets analyse the data on the basis of number of students who failed or passed in the exams-

# %%
data['math_PassStatus'] = np.where(data['math score']<40, 'Fail', 'Passed')
data['read_PassStatus'] = np.where(data['reading score']<40, 'Fail', 'Passed')
data['write_PassStatus'] = np.where(data['writing score']<40, 'Fail', 'Passed')

# %% [markdown]
# By running the following cells we can analyse graphically the number of students passed and failed-

# %%
print("Status of Maths")
data['math_PassStatus'].value_counts()
# Out:
# Status of Maths
# Passed    960
# Fail       40
# Name: math_PassStatus, dtype: int64

# %%
print("Status of Reading")
data['read_PassStatus'].value_counts()
# Out:
# Status of Reading
# Passed    974
# Fail       26
# Name: read_PassStatus, dtype: int64

# %%
print("Status of writing")
data['write_PassStatus'].value_counts()
# Out:
# Status of writing
# Passed    968
# Fail       32
# Name: write_PassStatus, dtype: int64

# %%
p = sns.countplot(x='parental level of education', data = data, hue='math_PassStatus', palette='bright')
_ = plt.setp(p.get_xticklabels(), rotation=90)

# %% [markdown]
# This graph shows us the number of students who passed or failed in maths arranged on the basis of their parental level of education.

# %%
p = sns.countplot(x='test preparation course', data = data, hue='math_PassStatus', palette='bright')
_ = plt.setp(p.get_xticklabels(), rotation=90)

# %% [markdown]
# This plot shows us the number of students who passed or failed in maths arranged on the basis of test preparation course.

# %%
p = sns.countplot(x='parental level of education', data = data, hue='read_PassStatus', palette='bright')
_ = plt.setp(p.get_xticklabels(), rotation=90)

# %% [markdown]
# This plot shows us the number of students who passed or failed in reading arranged on the basis of their parental level of education.

# %%
p = sns.countplot(x='test preparation course', data = data, hue='read_PassStatus', palette='bright')
_ = plt.setp(p.get_xticklabels(), rotation=90)

# %% [markdown]
# This graph shows us the number of students who passed or failed in reading on the basis of test preparation course.

# %%
p = sns.countplot(x='parental level of education', data = data, hue='write_PassStatus', palette='bright')
_ = plt.setp(p.get_xticklabels(), rotation=90)

# %% [markdown]
# This plot shows us the total number of students who passed or failed in writing on the basis of parental level of education.

# %%
p = sns.countplot(x='test preparation course', data = data, hue='write_PassStatus', palette='bright')
_ = plt.setp(p.get_xticklabels(), rotation=90)

# %% [markdown]
# This plot shows us the total number of students who passed or failed on the basis of test preparation course.

# %%
data.corr()
# Out:
#                math score  reading score  writing score     total   average
# math score       1.000000       0.817580       0.802642  0.918746  0.918746
# reading score    0.817580       1.000000       0.954598  0.970331  0.970331
# writing score    0.802642       0.954598       1.000000  0.965667  0.965667
# total            0.918746       0.970331       0.965667  1.000000  1.000000
# average          0.918746       0.970331       0.965667  1.000000  1.000000

# %% [markdown]
# The above data is displayed below in the form of a heat map.

# %%
plt.figure(figsize=(12,6))
sns.heatmap(data.corr(), annot=True, fmt='.1f')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='parental level of education', data = data, hue='gender')
plt.show()

# %% [markdown]
# The above bar graph shows the number of males and females coming from a background with different parental level of education.

# %%
print("Females of different race or ethnicity")
data['race/ethnicity'][data.gender=='female'].value_counts()
# Out:
# Females of different race or ethnicity
# group C    180
# group D    129
# group B    104
# group E     69
# group A     36
# Name: race/ethnicity, dtype: int64

# %%
print("Males of different race or ethnicity")
data['race/ethnicity'][data.gender=='male'].value_counts()
# Out:
# Males of different race or ethnicity
# group C    139
# group D    133
# group B     86
# group E     71
# group A     53
# Name: race/ethnicity, dtype: int64

# %%
print("Females having different types of lunch")
data['lunch'][data.gender=='female'].value_counts(normalize=True)
# Out:
# Females having different types of lunch
# standard        0.635135
# free/reduced    0.364865
# Name: lunch, dtype: float64

# %%
print("Males having different types of lunch")
data['lunch'][data.gender=='male'].value_counts(normalize=True)
# Out:
# Males having different types of lunch
# standard        0.655602
# free/reduced    0.344398
# Name: lunch, dtype: float64

# %%
sns.countplot(x='lunch', data = data, hue='gender', palette='bright')
plt.show()

# %% [markdown]
# The above plot shows the number of males and females having standard or free/reduced lunch.

# %% [markdown]
# Now, let us see to the different subject scores gender wise-

# %%
f1=data[data.gender=='female']
m1=data[data.gender=='male']
print("Math Scores")
print("Female:-")
print("-----------------------")
print(f1.groupby(['lunch','test preparation course'])['math score'].max().unstack(level = 'lunch'))
print("Male:-")
print("-----------------------")
print(m1.groupby(['lunch','test preparation course'])['math score'].max().unstack(level = 'lunch'))
# Out:
# Math Scores
# Female:-
# -----------------------
# lunch                    free/reduced  standard
# test preparation course
# completed                          93        99
# none                               81       100
# Male:-
# -----------------------
# lunch                    free/reduced  standard
# test preparation course
# completed                         100       100
# none                               93        97

# %%
print("Reading Scores")
print("Female:-")
print("-----------------------")
print(f1.groupby(['lunch','test preparation course'])['reading score'].max().unstack(level = 'lunch'))
print("Male:-")
print("-----------------------")
print(m1.groupby(['lunch','test preparation course'])['reading score'].max().unstack(level = 'lunch'))
# Out:
# Reading Scores
# Female:-
# -----------------------
# lunch                    free/reduced  standard
# test preparation course
# completed                         100       100
# none                               92       100
# Male:-
# -----------------------
# lunch                    free/reduced  standard
# test preparation course
# completed                         100       100
# none                               90        96

# %%
print("Writing Scores")
print("Female:-")
print("-----------------------")
print(f1.groupby(['lunch','test preparation course'])['writing score'].max().unstack(level = 'lunch'))
print("Male:-")
print("-----------------------")
print(m1.groupby(['lunch','test preparation course'])['writing score'].max().unstack(level = 'lunch'))
# Out:
# Writing Scores
# Female:-
# -----------------------
# lunch                    free/reduced  standard
# test preparation course
# completed                         100       100
# none                               93       100
# Male:-
# -----------------------
# lunch                    free/reduced  standard
# test preparation course
# completed                          93       100
# none                               83        92

# %%
print("Average Scores")
print("Female:-")
print("-----------------------")
print(f1.groupby(['lunch','test preparation course'])['average'].max().unstack(level = 'lunch'))
print("Male:-")
print("-----------------------")
print(m1.groupby(['lunch','test preparation course'])['average'].max().unstack(level = 'lunch'))
# Out:
# Average Scores
# Female:-
# -----------------------
# lunch                    free/reduced    standard
# test preparation course
# completed                   97.666667   99.666667
# none                        87.000000  100.000000
# Male:-
# -----------------------
# lunch                    free/reduced    standard
# test preparation course
# completed                   97.666667  100.000000
# none                        88.666667   93.666667

# %%
sns.barplot(x='gender', y='math score', data = data)

# %% [markdown]
# Hence, from the above plot we can say that in mathematics male students are better than female students.

# %%
sns.barplot(x='gender', y='reading score', data = data)

# %% [markdown]
# Similarly, we can say that female students are brighter than male students in reading.

# %%
sns.barplot(x='gender', y='writing score', data = data)

# %% [markdown]
# And, once again we see that female students are ahead of male students in writing too.

# %%
sns.barplot(x='gender', y='average', data = data)

# %% [markdown]
# Finally, the overall average when compared suggests that female students have done better than male students.
#
# Now let us see the data in different aspects-

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='average', data=data, palette='muted')
plt.show()

# %%
score_grouped = data.groupby("parental level of education", as_index=True)[["math score", "reading score", "writing score"]].mean().sort_values(by="writing score", ascending=False)
score_grouped.plot.bar(title="Students Average Score per Parental level of Education ")

# %%
plt.figure(figsize=(10,8))
sns.violinplot(x='parental level of education', y='average', data=data, kind='bar', hue='gender', palette='Set1')

# %%
plt.figure(figsize=(10,8))
sns.violinplot(x='test preparation course', y='average', data=data, kind='bar', hue='gender', palette='Set2')

# %%
data.plot(kind="scatter", x="reading score", y="average", alpha=0.5, color="red", grid=True, figsize=(10,10))
plt.xlabel("Reading Score", color="orange")
plt.ylabel("Average Score", color="blue")
plt.title("Average Score VS Reading Score")
plt.show()

# %%
data.plot(kind="scatter", x="writing score", y="average", alpha=0.5, color="blue", grid=True, figsize=(10,10))
plt.xlabel("Writing Score", color="orange")
plt.ylabel("Average Score", color="red")
plt.title("Average Score VS Writing Score")
plt.show()

# %%
data.plot(kind="scatter", x="math score", y="average", alpha=0.5, color="orange", grid=True, figsize=(10,10))
plt.xlabel("Math Score", color="red")
plt.ylabel("Average Score", color="blue")
plt.title("Average Score VS Math Score")
plt.show()

# %%
race_ethnicity = round(data.groupby(by = data["race/ethnicity"]).mean(), 1)
race_ethnicity
# Out:
#                 math score  reading score  writing score  total  average
# race/ethnicity
# group A               61.6           64.7           62.7  189.0     63.0
# group B               63.5           67.4           65.6  196.4     65.5
# group C               64.5           69.1           67.8  201.4     67.1
# group D               67.4           70.0           70.1  207.5     69.2
# group E               73.8           73.0           71.4  218.3     72.8

# %%
race_val = [89,190,319,262,140]
race_labels = ['Group A','Group B','Group C','Group D','Group E']
plt.pie(race_val, labels=race_labels, radius=1.5, autopct='%0.1f%%', shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x1ec48e35148>,
# ...
#  [Text(1.5859229437346671, 0.4553552640916412, 'Group A'),
#   Text(0.6647956155341775, 1.5101479363183379, 'Group B'),
#   Text(-1.5283384970994611, 0.6218371477193694, 'Group C'),
#   Text(-0.2170811704499172, -1.6356575941914293, 'Group D'),
#   Text(1.492964635253409, -0.7025358338779991, 'Group E')],
#  [Text(0.8650488784007274, 0.2483755985954406, '8.9%'),
#   Text(0.3626157902913695, 0.8237170561736387, '19.0%'),
#   Text(-0.8336391802360696, 0.3391838987560196, '31.9%'),
#   Text(-0.11840791115450026, -0.8921768695589612, '26.2%'),
#   Text(0.8143443465018593, -0.383201363933454, '14.0%')])

# %%
x = list(race_ethnicity.index)
y = round(race_ethnicity.mean(axis=1), 1)
fig, avgx = plt.subplots(figsize=(12,6))
rects = avgx.bar(x, y)
avgx.set_ylabel("Average Scores")
avgx.set_title("Average Scores by Race/Ethnicity")
avgx.set_xticklabels((x))
# Out:
# [Text(0, 0, 'group A'),
#  Text(0, 0, 'group B'),
#  Text(0, 0, 'group C'),
#  Text(0, 0, 'group D'),
#  Text(0, 0, 'group E')]
