# %% [markdown]
# # Restaurant GUI

# %%
from tkinter import *
from tkinter.ttk  import Combobox


def get_total():

                
                
                textinput=StringVar()


                e5=Entry(root,width=20,textvariable=textinput)
                e5.place(x=130,y=310)
                p=int(combo.get())*int(e3.get())
                t=(p*5)/100
                total=p+t

                textinput.set(total)
                
                
                
                
                
                




root=Tk()
root.geometry("500x500")
root.title("Bill System")

label=Label(root,text="****Food Restaurant****",bg="yellow",fg="Blue",font=("Arial",25))
label.pack()


label1=Label(root,text="Food item",font=("Arial",20))
label1.place(x=65,y=110)

l1=["Paratha","Dahi","Green Salad","Paneer","Chawmein","Veg Biryani","Fried Rice","Rasgulla","Ice cream","Hakka Noodles","Special BhelPuri"]

c1=Combobox(root,value=l1,width=15)




c1.place(x=250,y=120)


label2=Label(root,text="Quantity",font=("calibri",20))
label2.place(x=65,y=165)


list1=list(range(1,101))


combo=Combobox(root,value=list1,width=15)

combo.set("Select  Quantity")
combo.place(x=250,y=170)


label3=Label(root,text="Price",font=("calibri",20))
label3.place(x=65,y=220)


e3=Entry(root,width=25)
e3.place(x=250,y=230)

button=Button(root,text="Big Total With 5% Tax",width=20,font=("arial",10),command=get_total)
button.place(x=130,y=280)







root.mainloop()
